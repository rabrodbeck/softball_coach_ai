# %%
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
from dotenv import load_dotenv
from pathlib import Path
import os

load_dotenv()

# Load vectorstore from correct location
project_root = Path(os.getcwd()).parent
vectorstore_path = project_root / "vectorstore"

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

vectorstore = Chroma(
    persist_directory=str(vectorstore_path),
    embedding_function=embeddings
)

print(f"✅ Vectorstore loaded with {vectorstore._collection.count()} documents\n")

# Your test query
results = vectorstore.similarity_search(
    "how to teach a 12 year old to catch a fly ball",
    k=4
)

for i, r in enumerate(results):
    print(f"--- Result {i+1} ---")
    print(r.page_content[:450])
    print("---")
# Out:
# ✅ Vectorstore loaded with 99 documents
#
# --- Result 1 ---
# upon your kids is when they run after a fly ball, run first and reach and catch last. And that's when they're going to use their glove and catch it one-handed. And that's totally fine. Kids are capable of catching one-handed. And as a parent, you can help them break in their mid a little bit better, and that will make a lot of difference in their catching ability. So, as far as drills, what do you do to teach good catching habits in a young baseb
# ---
# --- Result 2 ---
# In this video, I'm going to teach you how to help your kid learn to catch, whether they're playing baseball or softball when they're just learning in the backyard. What should you do as a baseball or softball parent to help teach good catching skills for your son or daughter? In this video, we're going to go through all the basics and the big things that are important and dismiss some of the things that are not. So, in this video, we'll cover the
# ---
# ...
